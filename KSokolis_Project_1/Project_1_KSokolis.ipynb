# %% [markdown]
# # Project 1: SAT & ACT Analysis

# %% [markdown]
# The first markdown cell in a notebook is a great place to provide an overview of your entire project. You will likely want to at least state your
#
# ## Problem Statement
# Like Illinois, all states should be required to offer at least one of the two standard college entrance exams so all students upon exiting high school have nothing test-wise standing in their way in their pursuit of a secondary education.

# %% [markdown]
# as well as an

# %% [markdown]
# ## Executive Summary
#
# If you want to, it's great to use relative links to direct your audience to various sections of a notebook. **HERE'S A DEMONSTRATION WITH THE CURRENT SECTION HEADERS**:
#
# ### Contents:
# - [2017 Data Import & Cleaning](#Data-Import-and-Cleaning)
# - [2018 Data Import and Cleaning](#2018-Data-Import-and-Cleaning)
# - [Exploratory Data Analysis](#Exploratory-Data-Analysis)
# - [Data Visualization](#Visualize-the-data)
# - [Descriptive and Inferential Statistics](#Descriptive-and-Inferential-Statistics)
# - [Outside Research](#Outside-Research)
# - [Conclusions and Recommendations](#Conclusions-and-Recommendations)

# %% [markdown]
# **If you combine your problem statement, executive summary, data dictionary, and conclusions/recommendations, you have an amazing README.md file that quickly aligns your audience to the contents of your project.** Don't forget to cite your data sources!

# %% [markdown]
# *All libraries used should be added here*

# %%
#Imports:
import numpy as np
import scipy as sp
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ## 2017 Data Import and Cleaning

# %% [markdown]
# #### 1. Read In SAT & ACT  Data
#
# Read in the `sat_2017.csv` and `act_2017.csv` files and assign them to appropriately named pandas dataframes.

# %%
#Code:
act2017 = pd.read_csv('./data/act_2017.csv')
sat2017 = pd.read_csv('./data/sat_2017.csv')

# %% [markdown]
# #### 2. Display Data
#
# Print the first 10 rows of each dataframe to your jupyter notebook

# %%
#Code:
act2017.head(10)
# Out:
#                   State Participation  English  Math  Reading  Science  \
# 0              National           60%     20.3  20.7     21.4     21.0
# 1               Alabama          100%     18.9  18.4     19.7     19.4
# 2                Alaska           65%     18.7  19.8     20.4     19.9
# 3               Arizona           62%     18.6  19.8     20.1     19.8
# 4              Arkansas          100%     18.9  19.0     19.7     19.5
# 5            California           31%     22.5  22.7     23.1     22.2
# 6              Colorado          100%     20.1  20.3     21.2     20.9
# 7           Connecticut           31%     25.5  24.6     25.6     24.6
# 8              Delaware           18%     24.1  23.4     24.8     23.6
# 9  District of Columbia           32%     24.4  23.5     24.9     23.5
#
#   Composite
# 0      21.0
# 1      19.2
# 2      19.8
# 3      19.7
# 4      19.4
# 5      22.8
# 6      20.8
# 7      25.2
# 8      24.1
# 9      24.2

# %%
sat2017.head(10)
# Out:
#                   State Participation  Evidence-Based Reading and Writing  \
# 0               Alabama            5%                                 593
# 1                Alaska           38%                                 547
# 2               Arizona           30%                                 563
# 3              Arkansas            3%                                 614
# 4            California           53%                                 531
# 5              Colorado           11%                                 606
# 6           Connecticut          100%                                 530
# 7              Delaware          100%                                 503
# 8  District of Columbia          100%                                 482
# 9               Florida           83%                                 520
#
#    Math  Total
# 0   572   1165
# 1   533   1080
# 2   553   1116
# 3   594   1208
# 4   524   1055
# 5   595   1201
# 6   512   1041
# 7   492    996
# ...

# %%
act2017.shape
# Out:
# (52, 7)

# %%
sat2017.shape
# Out:
# (51, 5)

# %%
act2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 7 columns):
# State            52 non-null object
# Participation    52 non-null object
# English          52 non-null float64
# Math             52 non-null float64
# Reading          52 non-null float64
# Science          52 non-null float64
# Composite        52 non-null object
# dtypes: float64(4), object(3)
# memory usage: 2.9+ KB

# %%
sat2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
# State                                 51 non-null object
# Participation                         51 non-null object
# Evidence-Based Reading and Writing    51 non-null int64
# Math                                  51 non-null int64
# Total                                 51 non-null int64
# dtypes: int64(3), object(2)
# memory usage: 2.1+ KB

# %%
act2017
# Out:
#                    State Participation  English  Math  Reading  Science  \
# 0               National           60%     20.3  20.7     21.4     21.0
# 1                Alabama          100%     18.9  18.4     19.7     19.4
# 2                 Alaska           65%     18.7  19.8     20.4     19.9
# 3                Arizona           62%     18.6  19.8     20.1     19.8
# 4               Arkansas          100%     18.9  19.0     19.7     19.5
# 5             California           31%     22.5  22.7     23.1     22.2
# 6               Colorado          100%     20.1  20.3     21.2     20.9
# 7            Connecticut           31%     25.5  24.6     25.6     24.6
# 8               Delaware           18%     24.1  23.4     24.8     23.6
# 9   District of Columbia           32%     24.4  23.5     24.9     23.5
# 10               Florida           73%     19.0  19.4     21.0     19.4
# 11               Georgia           55%     21.0  20.9     22.0     21.3
# ...

# %%
sat2017
# Out:
#                    State Participation  Evidence-Based Reading and Writing  \
# 0                Alabama            5%                                 593
# 1                 Alaska           38%                                 547
# 2                Arizona           30%                                 563
# 3               Arkansas            3%                                 614
# 4             California           53%                                 531
# 5               Colorado           11%                                 606
# 6            Connecticut          100%                                 530
# 7               Delaware          100%                                 503
# 8   District of Columbia          100%                                 482
# 9                Florida           83%                                 520
# 10               Georgia           61%                                 535
# ...

# %% [markdown]
# #### 3. Verbally Describe Data
#
# Take your time looking through the data and thoroughly describe the data in the markdown cell below.

# %% [markdown]
# Answer: Every state is listed. The act also has a national average. There are no blanks. They have slightly different catagories.

# %% [markdown]
# #### 4a. Does the data look complete?

# %% [markdown]
# Answer: Yes. There are no blanks.

# %% [markdown]
# #### 4b. Are there any obvious issues with the observations?
#
# **What is the minimum *possible* value for each test/subtest? What is the maximum *possible* value?**
#
# Consider comparing any questionable values to the sources of your data:
# - [SAT](https://blog.collegevine.com/here-are-the-average-sat-scores-by-state/)
# - [ACT](https://blog.prepscholar.com/act-scores-by-state-averages-highs-and-lows)

# %% [markdown]
# Answer:
# The ACT data appears visually plausible with the exception of Maryland's science score being misentered. Currently it shows 2.3 when it should be 23.2. Also Wyoming composite has an 'x' at the end of it.
# The SAT data appears visually plausible with the exception of Maryland's math score which appears as though the entire number likely was not entered since the data shows 52 but the site shows 524.

# %% [markdown]
# #### 4c. Fix any errors you identified
#
# **The data is available** so there's no need to guess or calculate anything. If you didn't find any errors, continue to the next step.

# %%
#code
act2017.iloc[21,5] = '23.2'

# %%
act2017.iloc[21]
# Out:
# State            Maryland
# Participation         28%
# English              23.3
# Math                 23.1
# Reading              24.2
# Science              23.2
# Composite            23.6
# Name: 21, dtype: object

# %%
sat2017.iloc[20,3] = '524'

# %%
sat2017.iloc[20]
# Out:
# State                                 Maryland
# Participation                              69%
# Evidence-Based Reading and Writing         536
# Math                                       524
# Total                                     1060
# Name: 20, dtype: object

# %% [markdown]
# #### 5. What are your data types?
# Display the data types of each feature.

# %%
#code
act2017.dtypes
# Out:
# State             object
# Participation     object
# English          float64
# Math             float64
# Reading          float64
# Science           object
# Composite         object
# dtype: object

# %%
sat2017.dtypes
# Out:
# State                                 object
# Participation                         object
# Evidence-Based Reading and Writing     int64
# Math                                  object
# Total                                  int64
# dtype: object

# %% [markdown]
# What did you learn?
# - Do any of them seem odd?
# - Which ones are not as they should be?

# %% [markdown]
# Answer:
# ACT Science and Composite should be floats.
# SAT Math should be an integer.
# Both participations are oddly object when they should be int.

# %% [markdown]
# #### 6. Fix Incorrect Data Types
# Based on what you discovered above, use appropriate methods to re-type incorrectly typed data.
# - Define a function that will allow you to convert participation rates to an appropriate numeric type. Use `map` or `apply` to change these columns in each dataframe.

# %%
#code
act2017['Participation'] = act2017['Participation'].map(lambda participation_col: participation_col.replace('%', ''))

act2017['Participation'] = act2017['Participation'].astype(int)

sat2017['Participation'] = sat2017['Participation'].map(lambda participation_col: participation_col.replace('%', ''))

sat2017['Participation'] = sat2017['Participation'].astype(int)

# %% [markdown]
# - Fix any individual values preventing other columns from being the appropriate type.

# %%
act2017['Science'] = act2017['Science'].astype(float)

act2017.iloc[51,6] = 20.2

act2017.iloc[51,6]

act2017['Composite'] = act2017['Composite'].astype(float)

sat2017['Math'] = sat2017['Math'].astype(int)

# %% [markdown]
# - Finish your data modifications by making sure the columns are now typed appropriately.

# %% [markdown]
# - Display the data types again to confirm they are correct.

# %%
act2017.dtypes
# Out:
# State             object
# Participation      int64
# English          float64
# Math             float64
# Reading          float64
# Science          float64
# Composite        float64
# dtype: object

# %%
sat2017.dtypes
# Out:
# State                                 object
# Participation                          int64
# Evidence-Based Reading and Writing     int64
# Math                                   int64
# Total                                  int64
# dtype: object

# %% [markdown]
# #### 7. Rename Columns
# Change the names of the columns to more expressive names so that you can tell the difference the SAT columns and the ACT columns. Your solution should map all column names being changed at once (no repeated singular name-changes). **We will be combining these data with some of the data from 2018, and so you should name columns in an appropriate way**.
#
# **Guidelines**:
# - Column names should be all lowercase (you will thank yourself when you start pushing data to SQL later in the course)
# - Column names should not contain spaces (underscores will suffice--this allows for using the `df.column_name` method to access columns in addition to `df['column_name']`.
# - Column names should be unique and informative (the only feature that we actually share between dataframes is the state).

# %%
new_2017_act_col = {
    'State':'state',
    'Participation':'participation_percent_2017_act',
    'English':'english_2017_act',
    'Math':'math_2017_act',
    'Reading':'reading_2017_act',
    'Science':'science_2017_act',
    'Composite':'composite_2017_act'
}

act2017.rename(columns=new_2017_act_col, inplace=True)

new_2017_sat_col = {
    'State':'state',
    'Participation':'participation_percent_2017_sat',
    'Evidence-Based Reading and Writing':'reading_and_writing_2017_sat',
    'Math':'math_2017_sat',
    'Total':'total_2017_sat'
}

sat2017.rename(columns=new_2017_sat_col, inplace=True)

# %%
act2017.head()
# Out:
#       state  participation_percent_2017_act  english_2017_act  math_2017_act  \
# 0  National                              60              20.3           20.7
# 1   Alabama                             100              18.9           18.4
# 2    Alaska                              65              18.7           19.8
# 3   Arizona                              62              18.6           19.8
# 4  Arkansas                             100              18.9           19.0
#
#    reading_2017_act  science_2017_act  composite_2017_act
# 0              21.4              21.0                21.0
# 1              19.7              19.4                19.2
# 2              20.4              19.9                19.8
# 3              20.1              19.8                19.7
# 4              19.7              19.5                19.4

# %%
sat2017.head()
# Out:
#         state  participation_percent_2017_sat  reading_and_writing_2017_sat  \
# 0     Alabama                               5                           593
# 1      Alaska                              38                           547
# 2     Arizona                              30                           563
# 3    Arkansas                               3                           614
# 4  California                              53                           531
#
#    math_2017_sat  total_2017_sat
# 0            572            1165
# 1            533            1080
# 2            553            1116
# 3            594            1208
# 4            524            1055

# %% [markdown]
# #### 8. Create a data dictionary
#
# Now that we've fixed our data, and given it appropriate names, let's create a [data dictionary](http://library.ucmerced.edu/node/10249).
#
# A data dictionary provides a quick overview of features/variables/columns, alongside data types and descriptions. The more descriptive you can be, the more useful this document is.
#
# Example of a Fictional Data Dictionary Entry:
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |**county_pop**|*integer*|2010 census|The population of the county (units in thousands, where 2.5 represents 2500 people).|
# |**per_poverty**|*float*|2010 census|The percent of the county over the age of 18 living below the 200% of official US poverty rate (units percent to two decimal places 98.10 means 98.1%)|
#
# [Here's a quick link to a short guide for formatting markdown in Jupyter notebooks](https://jupyter-notebook.readthedocs.io/en/stable/examples/Notebook/Working%20With%20Markdown%20Cells.html).
#
# Provided is the skeleton for formatting a markdown table, with columns headers that will help you create a data dictionary to quickly summarize your data, as well as some examples. **This would be a great thing to copy and paste into your custom README for this project.**

# %% [markdown]
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |column name|int/float/object|ACT/SAT|This is an example|

# %% [markdown]
# |Feature|Type|Dataset|<div style="text-align: right"> Description  </div>|
# |---|---|---|---|
# |act      | dictionary |act_2017 | ACT averages from all 50 states.|
# |state_2017_act|object|act_2017|The state reporting ACT scores|
# |participation_percent_2017_act|integer|act_2017|Percentage of participation in the ACT from schools in the state listed.|
# |english_2017_act|float|act_2017|Average scores from the English portion of the ACT.|
# |math__2017_act|float|act_2017|Average scores from the Math portion of the ACT.|
# |reading_2017_act|float|act_2017|Average scores from the Reading portion of the ACT.|
# |science_2017_act|float|act_2017|Average scores from the Science portion of the ACT.|
# |composite_2017_act|float|act_2017|Average composite score for the ACT.|

# %% [markdown]
# |Feature|Type|Dataset|<div style="text-align: right"> Description  </div>|
# |---|---|---|---|
# |sat      | dictionary |sat_2017 | SAT averages from all 50 states.|
# |state_2017_sat|object|sat_2017|The state reporting SAT scores|
# |participation_percent_2017_sat|integer|sat_2017|Percentage of participation in the SAT from schools in the state listed.|
# |reading_and_writing_2017_sat|integer|sat_2017|Average scores from the Evidence-Based Reading and Writing portion of the SAT.|
# |math__2017_sat|integer|sat_2017|Average scores from the Math portion of the SAT.|
# |total_2017_sat|integer|sat_2017|Average Total score for the SAT.|

# %% [markdown]
# #### 9. Drop unnecessary rows
#
# One of our dataframes contains an extra row. Identify and remove this from the dataframe.

# %%
#code
act2017.drop(0, inplace=True)
act2017
# Out:
#                    state  participation_percent_2017_act  english_2017_act  \
# 1                Alabama                             100              18.9
# 2                 Alaska                              65              18.7
# 3                Arizona                              62              18.6
# 4               Arkansas                             100              18.9
# 5             California                              31              22.5
# 6               Colorado                             100              20.1
# 7            Connecticut                              31              25.5
# 8               Delaware                              18              24.1
# 9   District of Columbia                              32              24.4
# 10               Florida                              73              19.0
# 11               Georgia                              55              21.0
# ...

# %% [markdown]
# #### 10. Merge Dataframes
#
# Join the 2017 ACT and SAT dataframes using the state in each dataframe as the key. Assign this to a new variable.

# %%
#Code:
combined_2017 = pd.merge(act2017, sat2017, on='state')
combined_2017
# Out:
#                    state  participation_percent_2017_act  english_2017_act  \
# 0                Alabama                             100              18.9
# 1                 Alaska                              65              18.7
# 2                Arizona                              62              18.6
# 3               Arkansas                             100              18.9
# 4             California                              31              22.5
# 5               Colorado                             100              20.1
# 6            Connecticut                              31              25.5
# 7               Delaware                              18              24.1
# 8   District of Columbia                              32              24.4
# 9                Florida                              73              19.0
# 10               Georgia                              55              21.0
# ...

# %% [markdown]
# #### 11. Save your cleaned, merged dataframe
#
# Use a relative path to save out your data as `combined_2017.csv`.

# %%
#code
combined_2017.to_csv('../data/combined_2017.csv')

# %% [markdown]
# ## 2018 Data Import and Cleaning

# %% [markdown]
# Links to the 2018 ACT and SAT data are provided in the README. These data live in PDFs, and so you'll get to enjoy practicing some *manual* data collection. Save these data as a CSV in your `data` directory, and import, explore, and clean these data in the same way you did above. **Make sure you comment on your steps so it is clear *why* you are doing each process**.

# %%
# Thanks Brian!
act2018 = pd.read_csv('./data/act_2018.csv')
sat2018 = pd.read_csv('./data/sat_2018.csv')

# %% [markdown]
# #### Combine your 2017 and 2018 data into a single dataframe
# Joining on state names should work, assuming you formatted all your state names identically. Make sure none of your columns (other than state) have identical names. Do yourself a favor and decide if you're encoding participation rates as floats or integers and standardize this across your datasets.
#
# Save the contents of this merged dataframe as `final.csv`.
#
# **Use this combined dataframe for the remainder of the project**.

# %%
act2018['Participation'] = act2018['Participation'].map(lambda participation_col: participation_col.replace('%', ''))

act2018['Participation'] = act2018['Participation'].astype(int)

sat2018['Participation'] = sat2018['Participation'].map(lambda participation_col: participation_col.replace('%', ''))

sat2018['Participation'] = sat2018['Participation'].astype(int)

# %%
act2018.drop(51, inplace=True)

sat2018.drop(51, inplace=True)

# %%
new_2018_act_col = {
    'State':'state',
    'Participation':'participation_percent_2018_act',
    'English':'english_2018_act',
    'Math':'math_2018_act',
    'Reading':'reading_2018_act',
    'Science':'science_2018_act',
    'Composite':'composite_2018_act'
}

act2018.rename(columns=new_2018_act_col, inplace=True)

new_2018_sat_col = {
    'State':'state',
    'Participation':'participation_percent_2018_sat',
    'Evidence-Based Reading and Writing':'reading_and_writing_2018_sat',
    'Math':'math_2018_sat',
    'Total':'total_2018_sat'
}

sat2018.rename(columns=new_2018_sat_col, inplace=True)

# %%
combined_2018 = pd.merge(act2018, sat2018, on='state')

# %%
final = pd.merge(combined_2017, combined_2018, on='state')

# %%
final
# Out:
#                    state  participation_percent_2017_act  english_2017_act  \
# 0                Alabama                             100              18.9
# 1                 Alaska                              65              18.7
# 2                Arizona                              62              18.6
# 3               Arkansas                             100              18.9
# 4             California                              31              22.5
# 5               Colorado                             100              20.1
# 6            Connecticut                              31              25.5
# 7               Delaware                              18              24.1
# 8   District of Columbia                              32              24.4
# 9                Florida                              73              19.0
# 10               Georgia                              55              21.0
# ...

# %%
final.to_csv('../data/final.csv')

# %% [markdown]
# ## Exploratory Data Analysis
#
#
# ### Summary Statistics
# Transpose the output of pandas `describe` method to create a quick overview of each numeric feature.

# %%
#Code:
final.describe()
# Out:
#        participation_percent_2017_act  english_2017_act  math_2017_act  \
# count                       51.000000         51.000000      51.000000
# mean                        65.254902         20.931373      21.182353
# std                         32.140842          2.353677       1.981989
# min                          8.000000         16.300000      18.000000
# 25%                         31.000000         19.000000      19.400000
# 50%                         69.000000         20.700000      20.900000
# 75%                        100.000000         23.300000      23.100000
# max                        100.000000         25.500000      25.300000
#
#        reading_2017_act  science_2017_act  composite_2017_act  \
# count         51.000000         51.000000           51.000000
# mean          22.013725         21.450980           21.519608
# std            2.067271          1.739353            2.020695
# min           18.100000         18.200000           17.800000
# ...

# %%
final_for_graphing = final.drop(columns=['english_2017_act',
                                         'math_2017_act',
                                         'reading_2017_act',
                                         'science_2017_act',
                                         'reading_and_writing_2017_sat',
                                         'math_2017_sat',
                                         'reading_and_writing_2018_sat',
                                         'math_2018_sat'])
final_for_graphing
# Out:
#                    state  participation_percent_2017_act  composite_2017_act  \
# 0                Alabama                             100                19.2
# 1                 Alaska                              65                19.8
# 2                Arizona                              62                19.7
# 3               Arkansas                             100                19.4
# 4             California                              31                22.8
# 5               Colorado                             100                20.8
# 6            Connecticut                              31                25.2
# 7               Delaware                              18                24.1
# 8   District of Columbia                              32                24.2
# 9                Florida                              73                19.8
# 10               Georgia                              55                21.4
# ...

# %%
state_graph = final_for_graphing.drop(columns=[
    'participation_percent_2017_sat',
    'total_2017_sat',
    'participation_percent_2018_sat',
    'total_2018_sat',
    'composite_2017_act',
    'composite_2018_act',
    'participation_percent_2017_act',
    'participation_percent_2018_act'])

state_graph
# Out:
#                    state
# 0                Alabama
# 1                 Alaska
# 2                Arizona
# 3               Arkansas
# 4             California
# 5               Colorado
# 6            Connecticut
# 7               Delaware
# 8   District of Columbia
# 9                Florida
# 10               Georgia
# 11                Hawaii
# 12                 Idaho
# 13              Illinois
# 14               Indiana
# 15                  Iowa
# 16                Kansas
# 17              Kentucky
# 18             Louisiana
# 19                 Maine
# 20              Maryland
# 21         Massachusetts
# 22              Michigan
# 23             Minnesota
# 24           Mississippi
# 25              Missouri
# 26               Montana
# 27              Nebraska
# 28                Nevada
# 29         New Hampshire
# 30            New Jersey
# 31            New Mexico
# 32              New York
# 33        North Carolina
# 34          North Dakota
# 35                  Ohio
# ...

# %%
act_final_for_graphing = final_for_graphing.drop(columns=[
    'participation_percent_2017_sat',
    'total_2017_sat',
    'participation_percent_2018_sat',
    'total_2018_sat',
    'composite_2017_act',
    'composite_2018_act',
    'state'])

act_final_for_graphing
# Out:
#     participation_percent_2017_act  participation_percent_2018_act
# 0                              100                             100
# 1                               65                              33
# 2                               62                              66
# 3                              100                             100
# 4                               31                              27
# 5                              100                              30
# 6                               31                              26
# 7                               18                              17
# 8                               32                              32
# 9                               73                              66
# 10                              55                              53
# 11                              90                              89
# 12                              38                              36
# ...

# %% [markdown]
# #### Manually calculate standard deviation
#
# $$\sigma = \sqrt{\frac{1}{n}\sum_{i=1}^n(x_i - \mu)^2}$$
#
# - Write a function to calculate standard deviation using the formula above

# %%
import statistics as stats

# stats.stdev([])

# %%
std_final = final.describe().loc['std',:]
std_final
# Out:
# participation_percent_2017_act    32.140842
# english_2017_act                   2.353677
# math_2017_act                      1.981989
# reading_2017_act                   2.067271
# science_2017_act                   1.739353
# composite_2017_act                 2.020695
# participation_percent_2017_sat    35.276632
# reading_and_writing_2017_sat      45.666901
# math_2017_sat                     47.121395
# total_2017_sat                    92.494812
# participation_percent_2018_act    34.037085
# composite_2018_act                 2.111583
# participation_percent_2018_sat    37.300718
# reading_and_writing_2018_sat      45.311056
# math_2018_sat                     49.464862
# total_2018_sat                    94.444136
# Name: std, dtype: float64

# %% [markdown]
# Do your manually calculated standard deviations match up with the output from pandas `describe`? What about numpy's `std` method?

# %% [markdown]
# Answer
#
# Yes

# %% [markdown]
# #### Investigate trends in the data
# Using sorting and/or masking (along with the `.head` method to not print our entire dataframe), consider the following questions:
#
# - Which states have the highest and lowest participation rates for the:
#     - 2017 SAT?
#     - 2018 SAT?
#     - 2017 ACT?
#     - 2018 ACT?
# - Which states have the highest and lowest mean total/composite scores for the:
#     - 2017 SAT?
#     - 2018 SAT?
#     - 2017 ACT?
#     - 2018 ACT?
# - Do any states with 100% participation on a given test have a rate change year-to-year?
# - Do any states show have >50% participation on *both* tests either year?
#
# Based on what you've just observed, have you identified any states that you're especially interested in? **Make a note of these and state *why* you think they're interesting**.
#
# **You should comment on your findings at each step in a markdown cell below your code block**. Make sure you include at least one example of sorting your dataframe by a column, and one example of using boolean filtering (i.e., masking) to select a subset of the dataframe.

# %% [markdown]
# # 2017 SAT Highest Participation

# %%
sat2017.groupby(['participation_percent_2017_sat','state']).min().sort_values(['participation_percent_2017_sat','state'], ascending=False).head()
# Out:
#                                                      reading_and_writing_2017_sat  \
# participation_percent_2017_sat state
# 100                            Michigan                                       509
#                                District of Columbia                           482
#                                Delaware                                       503
#                                Connecticut                                    530
# 96                             New Hampshire                                  532
#
#                                                      math_2017_sat  \
# participation_percent_2017_sat state
# 100                            Michigan                        495
#                                District of Columbia            468
#                                Delaware                        492
#                                Connecticut                     512
# ...

# %% [markdown]
# # 2017 SAT Lowest Participation

# %%
sat2017.groupby(['participation_percent_2017_sat','state']).min().sort_values(['participation_percent_2017_sat','state'], ascending=True).head()
# Out:
#                                              reading_and_writing_2017_sat  \
# participation_percent_2017_sat state
# 2                              Iowa                                   641
#                                Mississippi                            634
#                                North Dakota                           635
# 3                              Arkansas                               614
#                                Minnesota                              644
#
#                                              math_2017_sat  total_2017_sat
# participation_percent_2017_sat state
# 2                              Iowa                    635            1275
#                                Mississippi             607            1242
#                                North Dakota            621            1256
# 3                              Arkansas                594            1208
# ...

# %% [markdown]
# # 2018 SAT Lowest Participation

# %%
sat2018.groupby(['participation_percent_2018_sat','state']).min().sort_values(['participation_percent_2018_sat','state'], ascending=True).head()
# Out:
#                                              reading_and_writing_2018_sat  \
# participation_percent_2018_sat state
# 2                              North Dakota                           640
# 3                              Iowa                                   634
#                                Nebraska                               629
#                                South Dakota                           622
#                                Wisconsin                              641
#
#                                              math_2018_sat  total_2018_sat
# participation_percent_2018_sat state
# 2                              North Dakota            643            1283
# 3                              Iowa                    631            1265
#                                Nebraska                623            1252
#                                South Dakota            618            1240
# ...

# %% [markdown]
# # 2018 SAT Highest Participation

# %%
sat2018.groupby(['participation_percent_2018_sat','state']).min().sort_values(['participation_percent_2018_sat','state'], ascending=False).head()
# Out:
#                                             reading_and_writing_2018_sat  \
# participation_percent_2018_sat state
# 100                            Michigan                              511
#                                Idaho                                 508
#                                Delaware                              505
#                                Connecticut                           535
# 99                             Maine                                 512
#
#                                             math_2018_sat  total_2018_sat
# participation_percent_2018_sat state
# 100                            Michigan               499            1010
#                                Idaho                  493            1001
#                                Delaware               492             997
#                                Connecticut            519            1054
# 99                             Maine                  501            1013

# %% [markdown]
# # 2017 ACT Highest Participation

# %%
act2017.groupby(['participation_percent_2017_act','state']).min().sort_values(['participation_percent_2017_act','state'], ascending=False).head()
# Out:
#                                                english_2017_act  \
# participation_percent_2017_act state
# 100                            Wyoming                     19.4
#                                Wisconsin                   19.7
#                                Utah                        19.5
#                                Tennessee                   19.5
#                                South Carolina              17.5
#
#                                                math_2017_act  \
# participation_percent_2017_act state
# 100                            Wyoming                  19.8
#                                Wisconsin                20.4
#                                Utah                     19.9
#                                Tennessee                19.2
#                                South Carolina           18.6
#
#                                                reading_2017_act  \
# participation_percent_2017_act state
# ...

# %% [markdown]
# # 2017 ACT Lowest Participation

# %%
act2017.groupby(['participation_percent_2017_act','state']).min().sort_values(['participation_percent_2017_act','state'], ascending=True).head()
# Out:
#                                               english_2017_act  math_2017_act  \
# participation_percent_2017_act state
# 8                              Maine                      24.2           24.0
# 18                             Delaware                   24.1           23.4
#                                New Hampshire              25.4           25.1
# 21                             Rhode Island               24.0           23.3
# 23                             Pennsylvania               23.4           23.4
#
#                                               reading_2017_act  \
# participation_percent_2017_act state
# 8                              Maine                      24.8
# 18                             Delaware                   24.8
#                                New Hampshire              26.0
# 21                             Rhode Island               24.7
# 23                             Pennsylvania               24.2
#
# ...

# %% [markdown]
# # 2018 ACT Lowest Participation

# %%
act2018.groupby(['participation_percent_2018_act','state']).min().sort_values(['participation_percent_2018_act','state'], ascending=True).head()
# Out:
#                                               composite_2018_act
# participation_percent_2018_act state
# 7                              Maine                        24.0
# 15                             Rhode Island                 24.2
# 16                             New Hampshire                25.1
# 17                             Delaware                     23.8
# 20                             Pennsylvania                 23.5

# %% [markdown]
# # 2018 ACT Highest Participation

# %%
act2018.groupby(['participation_percent_2018_act','state']).min().sort_values(['participation_percent_2018_act','state'], ascending=False).head()
# Out:
#                                                composite_2018_act
# participation_percent_2018_act state
# 100                            Wyoming                       20.0
#                                Wisconsin                     20.5
#                                Utah                          20.4
#                                Tennessee                     19.6
#                                South Carolina                18.3

# %% [markdown]
# # 2017 Highest Total SAT Score

# %%
sat2017.groupby(['total_2017_sat','state']).min().sort_values(['total_2017_sat','state'], ascending=False).head()
# Out:
#                           participation_percent_2017_sat  \
# total_2017_sat state
# 1295           Minnesota                               3
# 1291           Wisconsin                               3
# 1275           Iowa                                    2
# 1271           Missouri                                3
# 1260           Kansas                                  4
#
#                           reading_and_writing_2017_sat  math_2017_sat
# total_2017_sat state
# 1295           Minnesota                           644            651
# 1291           Wisconsin                           642            649
# 1275           Iowa                                641            635
# 1271           Missouri                            640            631
# 1260           Kansas                              632            628

# %% [markdown]
# # 2017 Lowest Total SAT Score

# %%
sat2017.groupby(['total_2017_sat','state']).min().sort_values(['total_2017_sat','state'], ascending=True).head()
# Out:
#                                      participation_percent_2017_sat  \
# total_2017_sat state
# 950            District of Columbia                             100
# 996            Delaware                                         100
# 1005           Idaho                                             93
#                Michigan                                         100
# 1012           Maine                                             95
#
#                                      reading_and_writing_2017_sat  \
# total_2017_sat state
# 950            District of Columbia                           482
# 996            Delaware                                       503
# 1005           Idaho                                          513
#                Michigan                                       509
# 1012           Maine                                          513
#
#                                      math_2017_sat
# total_2017_sat state
# ...

# %% [markdown]
# # 2018 Highest Total SAT Score

# %%
sat2018.groupby(['total_2018_sat','state']).min().sort_values(['total_2018_sat','state'], ascending=False).head()
# Out:
#                              participation_percent_2018_sat  \
# total_2018_sat state
# 1298           Minnesota                                  4
# 1294           Wisconsin                                  3
# 1283           North Dakota                               2
# 1272           Missouri                                   4
# 1265           Iowa                                       3
#
#                              reading_and_writing_2018_sat  math_2018_sat
# total_2018_sat state
# 1298           Minnesota                              643            655
# 1294           Wisconsin                              641            653
# 1283           North Dakota                           640            643
# 1272           Missouri                               633            639
# 1265           Iowa                                   634            631

# %% [markdown]
# # 2018 Lowest Total SAT Score

# %%
sat2018.groupby(['total_2018_sat','state']).min().sort_values(['total_2018_sat','state'], ascending=True).head()
# Out:
#                                      participation_percent_2018_sat  \
# total_2018_sat state
# 977            District of Columbia                              92
# 997            Delaware                                         100
# 999            West Virginia                                     28
# 1001           Idaho                                            100
# 1010           Michigan                                         100
#
#                                      reading_and_writing_2018_sat  \
# total_2018_sat state
# 977            District of Columbia                           497
# 997            Delaware                                       505
# 999            West Virginia                                  513
# 1001           Idaho                                          508
# 1010           Michigan                                       511
#
#                                      math_2018_sat
# total_2018_sat state
# ...

# %% [markdown]
# # 2017 Highest Composite ACT Score

# %%
act2017.groupby(['composite_2017_act','state']).min().sort_values(['composite_2017_act','state'], ascending=False).head()
# Out:
#                                   participation_percent_2017_act  \
# composite_2017_act state
# 25.5               New Hampshire                              18
# 25.4               Massachusetts                              29
# 25.2               Connecticut                                31
# 24.3               Maine                                       8
# 24.2               New York                                   31
#
#                                   english_2017_act  math_2017_act  \
# composite_2017_act state
# 25.5               New Hampshire              25.4           25.1
# 25.4               Massachusetts              25.4           25.3
# 25.2               Connecticut                25.5           24.6
# 24.3               Maine                      24.2           24.0
# 24.2               New York                   23.8           24.0
#
#                                   reading_2017_act  science_2017_act
# composite_2017_act state
# ...

# %% [markdown]
# # 2017 Lowest Composite ACT Score

# %%
act2017.groupby(['composite_2017_act','state']).min().sort_values(['composite_2017_act','state'], ascending=True).head()
# Out:
#                                    participation_percent_2017_act  \
# composite_2017_act state
# 17.8               Nevada                                     100
# 18.6               Mississippi                                100
# 18.7               South Carolina                             100
# 19.0               Hawaii                                      90
# 19.1               North Carolina                             100
#
#                                    english_2017_act  math_2017_act  \
# composite_2017_act state
# 17.8               Nevada                      16.3           18.0
# 18.6               Mississippi                 18.2           18.1
# 18.7               South Carolina              17.5           18.6
# 19.0               Hawaii                      17.8           19.2
# 19.1               North Carolina              17.8           19.3
#
#                                    reading_2017_act  science_2017_act
# composite_2017_act state
# ...

# %% [markdown]
# # 2018 Highest Composite ACT Score

# %%
act2018.groupby(['composite_2018_act','state']).min().sort_values(['composite_2018_act','state'], ascending=False).head()
# Out:
#                                   participation_percent_2018_act
# composite_2018_act state
# 25.6               Connecticut                                26
# 25.5               Massachusetts                              25
# 25.1               New Hampshire                              16
# 24.5               New York                                   27
# 24.2               Rhode Island                               15

# %% [markdown]
# # 2018 Lowest Composite ACT Score

# %%
act2018.groupby(['composite_2018_act','state']).min().sort_values(['composite_2018_act','state'], ascending=True).head()
# Out:
#                                    participation_percent_2018_act
# composite_2018_act state
# 17.7               Nevada                                     100
# 18.3               South Carolina                             100
# 18.6               Mississippi                                100
# 18.9               Hawaii                                      89
# 19.1               Alabama                                    100

# %%
act2018_lc = act2018.groupby(['composite_2018_act','state']).min().sort_values(['composite_2018_act','state'], ascending=True).head()

# %%
act2018_lc
# Out:
#                                    participation_percent_2018_act
# composite_2018_act state
# 17.7               Nevada                                     100
# 18.3               South Carolina                             100
# 18.6               Mississippi                                100
# 18.9               Hawaii                                      89
# 19.1               Alabama                                    100

# %% [markdown]
# ## Visualize the data
#
# There's not a magic bullet recommendation for the right number of plots to understand a given dataset, but visualizing your data is *always* a good idea. Not only does it allow you to quickly convey your findings (even if you have a non-technical audience), it will often reveal trends in your data that escaped you when you were looking only at numbers.
#
# Some recommendations on plotting:
# - Plots have titles
# - Plots have axis labels
# - Plots have appropriate tick labels
# - All text is legible in a plot
# - Plots demonstrate meaningful and valid relationships
# - Plots are interpreted to aid understanding
#
# There is such a thing as too many plots, and there are a *lot* of bad plots. You might make some! (But hopefully not with the guided prompts below).

# %% [markdown]
# #### Use Seaborn's heatmap with pandas `.corr()` to visualize correlations between all numeric features
#
# Heatmaps are generally not appropriate for presentations, and should often be excluded from reports as they can be visually overwhelming. **However**, they can be extremely useful in identify relationships of potential interest (as well as identifying potential collinearity before modeling).
#
# *example*:
# ```python
# sns.heatmap(df.corr())
# ```
#
# Please take time to format your output, adding a title. Look through some of the additional arguments and options. (Axis labels aren't really necessary, as long as the title is informative).

# %%
plt.figure()

# %%
plt.figure(figsize=(8,8))
sns.heatmap(final_for_graphing.corr(), annot=True)
plt.title('Participation vs. Total/Composite');

# %% [markdown]
# #### Define a custom function to subplot histograms
#
# We have data for two tests for two years. We only have composite (and not subtest scores) for the 2018 ACT. We should write a function that will take the names of 2+ columns and subplot histograms. While you can use pandas plotting or Seaborn here, matplotlib gives you greater control over all aspects of your plots.
#
# [Helpful Link for Plotting Multiple Figures](https://matplotlib.org/users/pyplot_tutorial.html#working-with-multiple-figures-and-axes)
#
# Here's some starter code:

# %%
def subplot_histograms(dataframe, 
                       list_of_columns, 
                       list_of_titles, 
                       list_of_xlabels):
    nrows = int(np.ceil(len(list_of_columns)/2)     # Makes sure you have enough rows
    plt.subplots(nrows=nrows, ncols=2)              # You'll want to specify your figsize
    ax = ax.ravel()                                 # Ravel turns a matrix into a vector, which is easier to iterate
    for i, column in enumerate(list_of_columns):    # Gives us an index value to get into all our lists
        ax[i].hist(dataframe[column])               # feel free to add more settings
                                                    # Set titles, labels, etc here for each subplot
# Out:
#   File "<ipython-input-63-9b4f0fcb3bd2>", line 6
#     plt.subplots(nrows=nrows, ncols=2)              # You'll want to specify your figsize
#       ^
# SyntaxError: invalid syntax

# %% [markdown]
# #### Plot and interpret histograms
# For each of the following:
# - Participation rates for SAT & ACT
# - Math scores for SAT & ACT
# - Reading/verbal scores for SAT & ACT

# %%
# Code

# %% [markdown]
# #### Plot and interpret scatter plots
#
# For each of the following:
# - SAT vs. ACT math scores for 2017
# - SAT vs. ACT verbal/reading scores for 2017
# - SAT vs. ACT total/composite scores for 2017
# - Total scores for SAT 2017 vs. 2018
# - Composite scores for ACT 2017 vs. 2018
#
# Plot the two variables against each other using matplotlib or Seaborn
#
# Your plots should show:
# - Two clearly labeled axes
# - A proper title
# - Using colors and symbols that are clear and unmistakable
#
# **Feel free to write a custom function, and subplot if you'd like.** Functions save both time and space.

# %%
# Code

# %% [markdown]
# #### Plot and interpret boxplots
#
# For each numeric variable in the dataframe create a boxplot using Seaborn. Boxplots demonstrate central tendency and spread in variables. In a certain sense, these are somewhat redundant with histograms, but you may be better able to identify clear outliers or differences in IQR, etc.
#
# Multiple values can be plotted to a single boxplot as long as they are of the same relative scale (meaning they have similar min/max values).
#
# Each boxplot should:
# - Only include variables of a similar scale
# - Have clear labels for each variable
# - Have appropriate titles and labels

# %%
# Code

# %% [markdown]
# #### Feel free to do additional plots below
# *(do research and choose your own chart types & variables)*
#
# Are there any additional trends or relationships you haven't explored? Was there something interesting you saw that you'd like to dive further into? It's likely that there are a few more plots you might want to generate to support your narrative and recommendations that you are building toward. **As always, make sure you're interpreting your plots as you go**.

# %% [markdown]
# #### (Optional): Using Tableau, create a choropleth map for each variable using a map of the US.
#
# Save this plot as an image file in an images directory, provide a relative path, and insert the image into notebook in markdown.

# %% [markdown]
# ## Descriptive and Inferential Statistics

# %% [markdown]
# #### Summarizing Distributions
#
# Above, we used pandas `describe` to provide quick summary statistics of our numeric columns. We also demonstrated many visual relationships.
#
# As data scientists, having a complete understanding of data is imperative prior to modeling.
#
# While we will continue to build our analytic tools, we know that measures of *central tendency*, *spread*, and *shape/skewness* provide a quick summary of distributions.
#
# For each variable in your data, summarize the underlying distributions (in words & statistics)
#  - Be thorough in your verbal description of these distributions.
#  - Be sure to back up these summaries with statistics.

# %% [markdown]
# Answers:

# %% [markdown]
# #### We generally assuming that data we sample from a population will be normally distributed. Do we observe this trend?

# %% [markdown]
# Answer:

# %% [markdown]
# Does This Assumption Hold for:
#     - Math
#     - Reading
#     - Rates
# Explain your answers for each distribution and how you think this will affect estimates made from these data.

# %% [markdown]
# Answer:

# %% [markdown]
# #### Estimate Limits of Data
#
# Suppose we only seek to understand the relationship between SAT and ACT participation rates in 2017.
#
# ##### Does it make sense to conduct statistical inference given these data specifically?
#
# Why or why not?
#
# *(think about granularity, aggregation, the relationships between populations size & rates...consider the actually populations these data describe in answering this question)*

# %% [markdown]
# Answer:

# %% [markdown]
# ##### Is it appropriate to compare *these* specific SAT and ACT math scores?
#
# Why or why not?

# %% [markdown]
# Answer:

# %% [markdown]
# #### Statistical Evaluation of Distributions
#
# **If you feel it's appropriate**, using methods we discussed in class, run hypothesis tests to compare variables of interest in our dataset.

# %%
# Code:

# %% [markdown]
# ## Outside Research

# %% [markdown]
# Based upon your observations, choose **three** states that demonstrate interesting trends in their SAT and/or ACT participation rates. Spend some time doing outside research on state policies that might influence these rates, and summarize your findings below. **Feel free to go back and create new plots that highlight these states of interest**. If you bring in any outside tables or charts, make sure you are explicit about having borrowed them. If you quote any text, make sure that it renders as being quoted. (Make sure that you cite your sources -- check with you local instructor for citation preferences).

# %% [markdown]
# ## Conclusions and Recommendations

# %% [markdown]
# Based on your exploration of the data, what are you key takeaways and recommendations? Choose one state with a lower participation rate and provide a suggestion for how the College Board might increase participation amongst graduating seniors in this state. Are there additional data you desire that would better inform your investigations?

# %%
final_for_graphing.iloc[13]
# Out:
# state                             Illinois
# participation_percent_2017_act          93
# composite_2017_act                    21.4
# participation_percent_2017_sat           9
# total_2017_sat                        1115
# participation_percent_2018_act          43
# composite_2018_act                    23.9
# participation_percent_2018_sat          99
# total_2018_sat                        1019
# Name: 13, dtype: object

# %%
final
# Out:
#                    state  participation_percent_2017_act  english_2017_act  \
# 0                Alabama                             100              18.9
# 1                 Alaska                              65              18.7
# 2                Arizona                              62              18.6
# 3               Arkansas                             100              18.9
# 4             California                              31              22.5
# 5               Colorado                             100              20.1
# 6            Connecticut                              31              25.5
# 7               Delaware                              18              24.1
# 8   District of Columbia                              32              24.4
# 9                Florida                              73              19.0
# 10               Georgia                              55              21.0
# ...

# %%
plt.figure(figsize = (30, 15))
plt.rcParams.update({'font.size': 22})

ax1 = plt.subplot()
ax1.bar(x=(final['state']), height=final['composite_2017_act'], color='blue')
ax1.set_title("2017 ACT Scores")
ax1.axhline(y=21.51, xmin=0, xmax=51, color='r')
plt.xticks(rotation=90)
plt.ylim(1, 36)
# Out:
# (1, 36)

# %%
plt.figure(figsize = (30, 15))
plt.rcParams.update({'font.size': 22})

ax1 = plt.subplot()
ax1.bar(x=(final['state']), height=final['composite_2018_act'], color='orange')
ax1.set_title("2018 ACT Scores")
ax1.axhline(y=21.49, xmin=0, xmax=51, color='r')
plt.xticks(rotation=90)
plt.ylim(1, 36)
# Out:
# (1, 36)

# %%
plt.figure(figsize = (30, 15))
plt.rcParams.update({'font.size': 22})

ax1 = plt.subplot()
ax1.bar(x=(final['state']), 
        height=final['participation_percent_2017_act'], 
        color='blue', 
        label="ACT")
ax1.set_title('2017 ACT Participation Percentage')

plt.xticks(rotation=90)
plt.ylim(1, 110);

# %%
plt.figure(figsize = (30, 15))
plt.rcParams.update({'font.size': 22})

ax1 = plt.subplot()
ax1.bar(x=(final['state']), 
        height=final['participation_percent_2018_act'], 
        color='blue', 
        label="ACT")
ax1.set_title('2018 ACT Participation Percentage')

plt.xticks(rotation=90)
plt.ylim(1, 110);

# %%
plt.figure(figsize = (30, 15))
plt.rcParams.update({'font.size': 22})

ax1 = plt.subplot()
ax1.bar(x=(final['state']), 
        height=final['participation_percent_2017_act'], 
        color='blue', 
        label="ACT")
ax1.set_title('2017 ACT vs. SAT Participation Percentage')

plt.xticks(rotation=90)
plt.ylim(1, 110)

ax2 = plt.subplot()
ax2.bar(x=(final['state']), 
        height=final['participation_percent_2017_sat'], 
        color='orange');
# Out:
# /anaconda3/lib/python3.6/site-packages/matplotlib/cbook/deprecation.py:107: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %%
plt.figure(figsize = (30, 15))
plt.rcParams.update({'font.size': 22})

ax1 = plt.subplot()
ax1.bar(x=(final['state']), 
        height=final['participation_percent_2018_act'], 
        color='blue', 
        label="ACT")
ax1.set_title('2018 ACT vs. SAT Participation Percentage')

plt.xticks(rotation=90)
plt.ylim(1, 110)

ax2 = plt.subplot()
ax2.bar(x=(final['state']), 
        height=final['participation_percent_2018_sat'], 
        color='orange');
# Out:
# /anaconda3/lib/python3.6/site-packages/matplotlib/cbook/deprecation.py:107: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %%
plt.figure(figsize = (5, 10))
plt.rcParams.update({'font.size': 22})

N=2
ind = np.arange(N)  # the x locations for the groups
width = 0.4       # the width of the bars


ax1 = plt.subplot()
ax1.bar(x=(final.iloc[13,0]), 
        height=final.iloc[13,1], 
        color='orange')
ax1.set_title('2017 ACT vs. SAT Participation Percentage')

plt.ylim(1, 110)

ax2 = plt.subplot()
ax2.bar(x=(final.iloc[13,0]), 
        height=final.iloc[13,6],
        color='blue')
plt.ylim(1, 110)

ax2.set_xticks(ind+width/2)
plt.gca().legend(('ACT','SAT'))
# Out:
# /anaconda3/lib/python3.6/site-packages/matplotlib/cbook/deprecation.py:107: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %%
def AvSpp_2018():
    plt.figure(figsize = (5, 10))
    plt.rcParams.update({'font.size': 22})

    N=2
    ind = np.arange(N)  # the x locations for the groups
    width = 0.4       # the width of the bars

    ax1 = plt.subplot()
    ax1.bar(x=(final.iloc[13,0]), 
            height=final.iloc[13,13], 
            color='orange')
    ax1.set_title('2018 ACT vs. SAT Participation Percentage')

    plt.ylim(1, 110)

    ax2 = plt.subplot()
    ax2.bar(x=(final.iloc[13,0]), 
            height=final.iloc[13,11],
            color='blue')
    plt.ylim(1, 110)

    ax2.set_xticks(ind+width/2)

    plt.gca().legend(('SAT','ACT'))
    
AvSpp_2018()
# Out:
# /anaconda3/lib/python3.6/site-packages/matplotlib/cbook/deprecation.py:107: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %%
plt.savefig('/Users/kylesokolis/Desktop/AvSpp_2018.png')
